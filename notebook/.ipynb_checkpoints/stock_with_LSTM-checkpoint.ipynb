# %%
#Kaggle link: https://www.kaggle.com/faressayah/stock-market-analysis-prediction-using-lstm/data?select=portfolio_data.csv

# %%
import pandas as pd
import os
import numpy as np
import pandas_datareader as web
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense, LSTM

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
plt.style.use('fivethirtyeight')

# %%
df = web.DataReader('AAPL', data_source='yahoo', start='2021-01-01', end='2021-09-01')

# %%
print(df.describe())
print(df.shape)
# Out:
#              High         Low        Open       Close        Volume  \
# count  168.000000  168.000000  168.000000  168.000000  1.680000e+02
# mean   134.954406  132.221785  133.580239  133.648988  9.162472e+07
# std      9.191099    9.257736    9.135357    9.306475  2.796504e+07
# min    120.400002  116.209999  119.029999  116.360001  4.639770e+07
# 25%    127.590000  125.129999  126.392502  126.082500  7.186898e+07
# 50%    133.584999  130.435005  132.145004  132.029999  8.831780e+07
# 75%    144.127506  140.475002  142.830002  142.567497  1.056470e+08
# max    154.979996  152.339996  152.830002  153.119995  1.855495e+08
#
#         Adj Close
# count  168.000000
# mean   133.335013
# std      9.384978
# min    115.988907
# 25%    125.786032
# 50%    131.556030
# 75%    142.240578
# max    153.119995
# (168, 6)

# %%
plt.figure(figsize=(10,5))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD')
plt.show()

# %%
#Process the data

data = df.filter(['Close'])

print('Data shape: ', data.shape)
#Define training portion
train_ratio = 0.8
train_length = math.ceil(train_ratio * len(data))
test_length = len(data) - train_length
print('Training ratio: ', train_length)
print('Test ratio: ', test_length)
#Scale the data
scaler = MinMaxScaler(feature_range = (0,1))
scaled_data = scaler.fit_transform(data)

print(scaled_data)
# Out:
# Data shape:  (168, 1)
# Training ratio:  135
# Test ratio:  33
# [[0.35500558]
#  [0.39853091]
#  [0.27856364]
#  [0.39608269]
#  [0.42682276]
#  [0.34330786]
#  [0.33841143]
#  [0.39526662]
#  [0.34140383]
#  [0.29325355]
#  [0.31202402]
#  [0.42627858]
#  [0.55794335]
#  [0.61779135]
#  [0.72252452]
#  [0.72905351]
#  [0.69912951]
#  [0.56392815]
#  [0.42437455]
#  [0.48367795]
#  [0.50680108]
#  [0.47823734]
#  [0.57208928]
#  [0.55495095]
#  [0.55903172]
#  [0.53454834]
#  [0.51768231]
#  [0.51060955]
#  [0.51713812]
#  [0.45783472]
#  [0.39390636]
#  [0.36316671]
#  [0.36751895]
#  [0.26224159]
#  [0.25843312]
#  [0.24455928]
#  [0.12595207]
#  [0.13329712]
#  [0.31093585]
#  [0.2383026 ]
#  [0.15505979]
#  [0.10255705]
#  [0.13764957]
#  [0.        ]
#  [0.12867237]
#  [0.09847669]
#  [0.15233948]
#  [0.12704023]
#  [0.20756252]
#  [0.25054408]
#  [0.22850932]
#  [0.11343849]
#  [0.09874858]
#  [0.19124047]
#  [0.16811755]
#  [0.10146889]
#  [0.11507063]
#  [0.13193687]
#  [0.1368335 ]
#  [0.09630037]
#  [0.15750821]
#  [0.18063113]
#  [0.25952128]
#  [0.2679543 ]
#  [0.31392825]
#  [0.38084881]
#  [0.45266599]
#  [0.40478801]
#  [0.49156678]
#  [0.42627858]
#  [0.49347122]
#  [0.48422214]
#  [0.50272031]
#  [0.45565839]
#  [0.46626774]
#  [0.42383036]
#  [0.48857479]
#  [0.49945602]
#  [0.49047882]
#  [0.46844406]
#  [0.46572355]
#  [0.41077281]
#  [0.44015221]
#  [0.312568  ]
#  [0.31936908]
#  [0.36398278]
#  [0.37676845]
#  [0.28536451]
#  [0.25979338]
#  [0.17437424]
#  [0.23422203]
#  [0.30168656]
#  [0.26958644]
#  [0.23095754]
#  [0.22660509]
#  [0.29787809]
#  [0.24673561]
#  [0.29216538]
#  [0.28672477]
#  [0.28536451]
#  [0.24265505]
#  [0.22442876]
#  [0.21545156]
#  [0.23667025]
#  [0.19532104]
#  [0.25924919]
#  [0.25952128]
#  [0.28237211]
#  [0.29298145]
#  [0.26523399]
#  [0.29896625]
#  [0.38411309]
#  [0.36126226]
#  [0.37513589]
#  [0.41974959]
#  [0.38356932]
#  [0.43362364]
#  [0.47932529]
#  [0.47170835]
#  [0.46381952]
#  [0.45565839]
#  [0.50108816]
#  [0.54325365]
#  [0.56039198]
#  [0.56882499]
#  [0.64200244]
#  [0.69804155]
#  [0.76741053]
#  [0.73122984]
#  [0.78210023]
#  [0.76550608]
#  [0.79651804]
#  [0.89200213]
#  [0.87377584]
#  [0.81692065]
#  [0.70973885]
#  [0.81039167]
#  [0.78998905]
#  [0.82807418]
#  [0.87595217]
#  [0.88764988]
#  [0.82725811]
#  [0.77856364]
#  [0.79651804]
#  [0.80250284]
#  [0.79325375]
#  [0.84330807]
#  [0.83215454]
#  [0.83514694]
#  [0.81011978]
#  [0.80875953]
#  [0.79543008]
#  [0.80250284]
#  [0.88492937]
#  [0.89064228]
#  [0.94559303]
#  [0.92029398]
#  [0.81610458]
#  [0.82535367]
#  [0.86588701]
#  [0.90723643]
#  [0.9047878 ]
#  [0.87051156]
#  [0.8482045 ]
#  [0.87704054]
#  [1.        ]
#  [0.96490769]
#  [0.98340586]]

# %%
#Create a training dataset
train_data = scaled_data[0: train_length, :]
x_train = []
y_train = []

batch = 60

for i in range(batch, len(train_data)):
    x_train.append(train_data[i - batch: i, 0])
    y_train.append(train_data[i])
    
    if i == batch + 1: 
        print(x_train)
        print(y_train)
        
#Convert to numpy array
x_train, y_train = np.array(x_train ), np.array(y_train)
# Out:
# [array([0.35500558, 0.39853091, 0.27856364, 0.39608269, 0.42682276,
#        0.34330786, 0.33841143, 0.39526662, 0.34140383, 0.29325355,
#        0.31202402, 0.42627858, 0.55794335, 0.61779135, 0.72252452,
#        0.72905351, 0.69912951, 0.56392815, 0.42437455, 0.48367795,
#        0.50680108, 0.47823734, 0.57208928, 0.55495095, 0.55903172,
#        0.53454834, 0.51768231, 0.51060955, 0.51713812, 0.45783472,
#        0.39390636, 0.36316671, 0.36751895, 0.26224159, 0.25843312,
#        0.24455928, 0.12595207, 0.13329712, 0.31093585, 0.2383026 ,
#        0.15505979, 0.10255705, 0.13764957, 0.        , 0.12867237,
#        0.09847669, 0.15233948, 0.12704023, 0.20756252, 0.25054408,
#        0.22850932, 0.11343849, 0.09874858, 0.19124047, 0.16811755,
#        0.10146889, 0.11507063, 0.13193687, 0.1368335 , 0.09630037]), array([0.39853091, 0.27856364, 0.39608269, 0.42682276, 0.34330786,
#        0.33841143, 0.39526662, 0.34140383, 0.29325355, 0.31202402,
#        0.42627858, 0.55794335, 0.61779135, 0.72252452, 0.72905351,
#        0.69912951, 0.56392815, 0.42437455, 0.48367795, 0.50680108,
#        0.47823734, 0.57208928, 0.55495095, 0.55903172, 0.53454834,
#        0.51768231, 0.51060955, 0.51713812, 0.45783472, 0.39390636,
#        0.36316671, 0.36751895, 0.26224159, 0.25843312, 0.24455928,
#        0.12595207, 0.13329712, 0.31093585, 0.2383026 , 0.15505979,
#        0.10255705, 0.13764957, 0.        , 0.12867237, 0.09847669,
#        0.15233948, 0.12704023, 0.20756252, 0.25054408, 0.22850932,
#        0.11343849, 0.09874858, 0.19124047, 0.16811755, 0.10146889,
#        0.11507063, 0.13193687, 0.1368335 , 0.09630037, 0.15750821])]
# [array([0.15750821]), array([0.18063113])]

# %%
print('Original train shape ', x_train.shape)
print('Original Train label shape ', y_train.shape)
#Reshape the data for LSTM model
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

print("Train shape ", x_train.shape)
# Out:
# Original train shape  (75, 60, 1)
# Original Train label shape  (75, 1)
# Train shape  (75, 60, 1)

# %%
#Building the model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))

#Compile
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
epochs = 10

#Train the model
model.fit(x_train, y_train, batch_size = 1, epochs = epochs)
# Out:
# Epoch 1/10
# 75/75 [==============================] - 17s 226ms/step - loss: 0.0287
# Epoch 2/10
# 75/75 [==============================] - 14s 186ms/step - loss: 0.0111
# Epoch 3/10
# 75/75 [==============================] - 13s 167ms/step - loss: 0.0070
# Epoch 4/10
# 75/75 [==============================] - 12s 158ms/step - loss: 0.0060
# Epoch 5/10
# 75/75 [==============================] - 13s 171ms/step - loss: 0.0069
# Epoch 6/10
# 75/75 [==============================] - 13s 174ms/step - loss: 0.0049
# Epoch 7/10
# 75/75 [==============================] - 13s 172ms/step - loss: 0.0052
# Epoch 8/10
# 75/75 [==============================] - 14s 183ms/step - loss: 0.0047
# Epoch 9/10
# 75/75 [==============================] - 14s 185ms/step - loss: 0.0044
# Epoch 10/10
# 75/75 [==============================] - 14s 182ms/step - loss: 0.0040

# %%
print(data.shape)

#Create test dataset
test_data = scaled_data[train_length - batch:, :]

x_test = []
y_test = data.values[train_length: , :]
for i in range(batch, len(test_data)):
    x_test.append(test_data[i - batch: i, 0])

#Convert to numpy and reshape
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

print(x_test.shape)
# Out:
# (168, 1)
# (33, 60, 1)

# %%
#Make predictions

predictions = model.predict(x_train)
predictions = scaler.inverse_transform(predictions)

print(predictions)

rmse = np.sqrt(mean_squared_error(y_train, predictions))
print(rmse)
# Out:
# [[122.48478 ]
#  [122.56707 ]
#  [122.97464 ]
#  [124.00363 ]
#  [125.24768 ]
#  [126.72228 ]
#  [128.55727 ]
#  [130.81984 ]
#  [132.53426 ]
#  [134.3479  ]
#  [135.30002 ]
#  [136.15414 ]
#  [136.64948 ]
#  [136.96153 ]
#  [136.63275 ]
#  [136.05928 ]
#  [135.02557 ]
#  [134.44447 ]
#  [134.23343 ]
#  [134.13521 ]
#  [133.89423 ]
#  [133.57729 ]
#  [132.79068 ]
#  [132.14456 ]
#  [130.62506 ]
#  [129.02388 ]
#  [128.02272 ]
#  [127.610756]
#  [126.89973 ]
#  [126.02134 ]
#  [124.64666 ]
#  [123.74321 ]
#  [123.73767 ]
#  [124.0066  ]
#  [124.14877 ]
#  [124.218475]
#  [124.77431 ]
#  [125.15565 ]
#  [125.73665 ]
#  [126.30311 ]
#  [126.774635]
#  [126.82153 ]
#  [126.52713 ]
#  [126.05573 ]
#  [125.73084 ]
#  [125.25257 ]
#  [125.2321  ]
#  [125.452835]
#  [125.92976 ]
#  [126.54007 ]
#  [126.92096 ]
#  [127.36716 ]
#  [128.39536 ]
#  [129.37192 ]
#  [130.25632 ]
#  [131.27574 ]
#  [131.87685 ]
#  [132.5375  ]
#  [133.4544  ]
#  [134.24577 ]
#  [134.73055 ]
#  [134.85887 ]
#  [135.12514 ]
#  [135.73341 ]
#  [136.52127 ]
#  [137.29971 ]
#  [138.56766 ]
#  [140.35909 ]
#  [142.76033 ]
#  [144.65477 ]
#  [146.40756 ]
#  [147.50801 ]
#  [148.29826 ]
#  [149.70876 ]
#  [150.8899  ]]
# 131.2523654565989
